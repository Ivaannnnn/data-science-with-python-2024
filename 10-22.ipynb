# %%
import pandas as pd
from sklearn import datasets

iris = datasets.load_iris()

df_iris = pd.DataFrame(data=iris.data, columns=iris.feature_names)

df_iris['species'] = iris.target
df_iris['species'] = df_iris['species'].map({0: 'setosa', 1: 'versicolor', 2: 'virginica'})

df_iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
df_iris.info()

df_iris.describe()

df_iris['species'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   species            150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.pairplot(df_iris, hue="species", diag_kind="kde")
plt.show()

plt.figure(figsize=(8, 6))
sns.boxplot(data=df_iris, orient='h')
plt.title("Feature Distribution of Iris Dataset")
plt.show()

# %%
df_iris.to_csv("iris_dataset.csv", index=False)
print("Iris dataset saved as 'iris_dataset.csv'")
# Out:
# Iris dataset saved as 'iris_dataset.csv'

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\ivanf\anaconda3\lib\site-packages (0.2.51)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\ivanf\anaconda3\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\ivanf\anaconda3\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\ivanf\anaconda3\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\ivanf\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\ivanf\anaconda3\lib\site-packages (from yfinance) (5.2.1)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\ivanf\anaconda3\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\ivanf\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\ivanf\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\ivanf\anaconda3\lib\site-packages (from yfinance) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\ivanf\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in c:\users\ivanf\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ivanf\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in c:\users\ivanf\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\ivanf\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ivanf\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ivanf\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ivanf\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ivanf\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ivanf\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ivanf\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2024.12.14)

# %%
import yfinance as yf

# %%
nvda = yf.download("NVDA", period="1y")

nvda.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           NVDA       NVDA       NVDA       NVDA       NVDA
# Date
# 2024-01-29  62.447292  62.471284  60.889735  61.214640  348733000
# 2024-01-30  62.756207  63.475004  62.242352  62.882174  410735000
# 2024-01-31  61.509563  62.251354  60.682798  61.422586  453795000
# 2024-02-01  63.009136  63.173091  61.632528  62.082397  369146000
# 2024-02-02  66.141251  66.581121  63.671946  63.955866  476578000

# %%
nvda.info()

nvda.describe()

nvda.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 251 entries, 2024-01-29 to 2025-01-28
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   (Close, NVDA)     251 non-null    float64
#  1   (High, NVDA)      251 non-null    float64
#  2   (Low, NVDA)       251 non-null    float64
#  3   (Open, NVDA)      251 non-null    float64
#  4   (Volume, NVDA)    251 non-null    int64
#  5   (50_MA, )         202 non-null    float64
#  6   (Daily_Return, )  250 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 15.7 KB
# Price         Ticker
# Close         NVDA       0
# High          NVDA       0
# Low           NVDA       0
# Open          NVDA       0
# Volume        NVDA       0
# 50_MA                   49
# Daily_Return             1
# dtype: int64

# %%
plt.figure(figsize=(12, 6))
plt.plot(nvda.index, nvda['Close'], label="NVIDIA Stock Price", color='green')
plt.xlabel("Date")
plt.ylabel("Stock Price (USD)")
plt.title("NVIDIA Stock Price Over the Last Year")
plt.legend()
plt.show()

# %%
nvda.to_csv("nvidia_stock_data.csv")
print("NVIDIA stock data saved as 'nvidia_stock_data.csv'")
# Out:
# NVIDIA stock data saved as 'nvidia_stock_data.csv'

# %%
df_iris.info()

df_iris.describe()

df_iris.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   species            150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# species              0
# dtype: int64

# %%
sns.pairplot(df_iris, hue="species", diag_kind="kde")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df_iris, orient='h')
plt.title("Feature Distribution of Iris Dataset")
plt.show()

# %%
nvda.info()

nvda.describe()

nvda.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 251 entries, 2024-01-29 to 2025-01-28
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (Close, NVDA)   251 non-null    float64
#  1   (High, NVDA)    251 non-null    float64
#  2   (Low, NVDA)     251 non-null    float64
#  3   (Open, NVDA)    251 non-null    float64
#  4   (Volume, NVDA)  251 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 11.8 KB
# Price   Ticker
# Close   NVDA      0
# High    NVDA      0
# Low     NVDA      0
# Open    NVDA      0
# Volume  NVDA      0
# dtype: int64

# %%
plt.figure(figsize=(12, 6))
plt.plot(nvda.index, nvda['Close'], label="NVIDIA Stock Price", color='blue')
plt.xlabel("Date")
plt.ylabel("Stock Price (USD)")
plt.title("NVIDIA Stock Price Over Time")
plt.legend()
plt.show()

# %%
nvda['50_MA'] = nvda['Close'].rolling(window=50).mean()  # 50-day moving average
plt.figure(figsize=(12, 6))
plt.plot(nvda.index, nvda['Close'], label="Closing Price", color='blue')
plt.plot(nvda.index, nvda['50_MA'], label="50-Day MA", color='red')
plt.xlabel("Date")
plt.ylabel("Stock Price (USD)")
plt.title("NVIDIA Stock Price with 50-Day Moving Average")
plt.legend()
plt.show()

# %%
nvda['Daily_Return'] = nvda['Close'].pct_change()
sns.histplot(nvda['Daily_Return'].dropna(), bins=50, kde=True)
plt.title("Distribution of Daily Returns")
plt.show()
